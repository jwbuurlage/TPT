# %%
# %matplotlib inline

import tomo

# %%
k = 128
volume = tomo.volume(k, k)
phantom = tomo.modified_sl_phantom(volume)
tomo.plot(phantom)

# %%
geometry = tomo.parallel_geometry(k // 2, k // 2, volume)
sino = tomo.forward_project(phantom, geometry)
tomo.plot(sino)

# %%
art_result = tomo.art(volume, geometry, sino, 0.5, 1)
tomo.plot(art_result)

# %%
sart_result = tomo.sart(volume, geometry, sino, 0.5, 10)
tomo.plot(sart_result)

# %%
sirt_result = tomo.sirt(volume, geometry, sino, 0.5, 100)
tomo.plot(sirt_result)

# %%
large = 512
large_volume = tomo.volume(large, large)
large_phantom = tomo.modified_sl_phantom(large_volume)
tomo.plot(large_phantom)

# %%
large_geometry = tomo.parallel_geometry(large // 4, large // 4, large_volume)
large_sino = tomo.forward_project(large_phantom, large_geometry)

# %%
tomo.plot(tomo.sirt(large_volume, large_geometry, large_sino, 0.5, 5))

# %%
tomo.test_algorithm(tomo.art, volume, geometry, sino, [0.3, 0.5, 0.7], [1,5,10,20])

# %%
tomo.test_algorithm(tomo.sirt, volume, geometry, sino, [0.3, 0.5, 0.7], [1,5,10,20])
