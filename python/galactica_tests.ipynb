# %%
# %matplotlib inline

import tomo

# %%
k = 128
volume = tomo.volume(k, k)
phantom = tomo.modified_sl_phantom(volume)
tomo.plot(phantom)

# %%
geometry = tomo.parallel_geometry(k // 2, k // 2, volume)

# %%
help(tomo.fb)
# Out:
# Help on built-in function fb in module py_galactica:
#
# fb(...) method of builtins.PyCapsule instance
#     fb(py_galactica.image, py_galactica.parallel_geometry) -> py_galactica.sinogram
#
#     forward project phantom

# %%
sino = tomo.fb(phantom, geometry)

# %%
tomo.plot(sino)

# %%
result = tomo.art(volume, geometry, sino, 0.5)

# %%
tomo.plot(result)
