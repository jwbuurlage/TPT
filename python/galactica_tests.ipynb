# %%
# %matplotlib inline

import tomo

# %%
k = 256
volume = tomo.volume(k, k)
phantom = tomo.modified_sl_phantom(volume)
tomo.plot(phantom)

# %%
geometry = tomo.parallel_geometry(k, k, volume)
sino = tomo.forward_project(phantom, geometry)
tomo.plot(sino)

# %%
tomo.test_algorithm(tomo.art_iteration, volume, geometry, sino, [0.3, 0.5, 0.7], [1,5,10,20, 50, 100], phantom)
